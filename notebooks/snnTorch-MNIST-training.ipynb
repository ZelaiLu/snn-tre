# %%
# %pip install snntorch
# Out:
# Requirement already satisfied: snntorch in /home/alessandro/tesi/tesi-python/lib/python3.10/site-packages (0.5.3)
# Requirement already satisfied: matplotlib in /home/alessandro/tesi/tesi-python/lib/python3.10/site-packages (from snntorch) (3.6.2)
# Requirement already satisfied: pandas in /home/alessandro/tesi/tesi-python/lib/python3.10/site-packages (from snntorch) (1.5.2)
# Requirement already satisfied: numpy>=1.17 in /home/alessandro/tesi/tesi-python/lib/python3.10/site-packages (from snntorch) (1.23.5)
# Requirement already satisfied: torch>=1.1.0 in /home/alessandro/tesi/tesi-python/lib/python3.10/site-packages (from snntorch) (1.13.0)
# Requirement already satisfied: typing-extensions in /home/alessandro/tesi/tesi-python/lib/python3.10/site-packages (from torch>=1.1.0->snntorch) (4.4.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu11==11.7.99 in /home/alessandro/tesi/tesi-python/lib/python3.10/site-packages (from torch>=1.1.0->snntorch) (11.7.99)
# Requirement already satisfied: nvidia-cudnn-cu11==8.5.0.96 in /home/alessandro/tesi/tesi-python/lib/python3.10/site-packages (from torch>=1.1.0->snntorch) (8.5.0.96)
# Requirement already satisfied: nvidia-cuda-runtime-cu11==11.7.99 in /home/alessandro/tesi/tesi-python/lib/python3.10/site-packages (from torch>=1.1.0->snntorch) (11.7.99)
# Requirement already satisfied: nvidia-cublas-cu11==11.10.3.66 in /home/alessandro/tesi/tesi-python/lib/python3.10/site-packages (from torch>=1.1.0->snntorch) (11.10.3.66)
# Requirement already satisfied: wheel in /home/alessandro/tesi/tesi-python/lib/python3.10/site-packages (from nvidia-cublas-cu11==11.10.3.66->torch>=1.1.0->snntorch) (0.38.4)
# Requirement already satisfied: setuptools in /home/alessandro/tesi/tesi-python/lib/python3.10/site-packages (from nvidia-cublas-cu11==11.10.3.66->torch>=1.1.0->snntorch) (59.6.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /home/alessandro/tesi/tesi-python/lib/python3.10/site-packages (from matplotlib->snntorch) (1.4.4)
# Requirement already satisfied: fonttools>=4.22.0 in /home/alessandro/tesi/tesi-python/lib/python3.10/site-packages (from matplotlib->snntorch) (4.38.0)
# Requirement already satisfied: contourpy>=1.0.1 in /home/alessandro/tesi/tesi-python/lib/python3.10/site-packages (from matplotlib->snntorch) (1.0.6)
# Requirement already satisfied: packaging>=20.0 in /home/alessandro/tesi/tesi-python/lib/python3.10/site-packages (from matplotlib->snntorch) (22.0)
# Requirement already satisfied: pyparsing>=2.2.1 in /home/alessandro/tesi/tesi-python/lib/python3.10/site-packages (from matplotlib->snntorch) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in /home/alessandro/tesi/tesi-python/lib/python3.10/site-packages (from matplotlib->snntorch) (2.8.2)
# Requirement already satisfied: cycler>=0.10 in /home/alessandro/tesi/tesi-python/lib/python3.10/site-packages (from matplotlib->snntorch) (0.11.0)
# Requirement already satisfied: pillow>=6.2.0 in /home/alessandro/tesi/tesi-python/lib/python3.10/site-packages (from matplotlib->snntorch) (9.3.0)
# Requirement already satisfied: pytz>=2020.1 in /home/alessandro/tesi/tesi-python/lib/python3.10/site-packages (from pandas->snntorch) (2022.6)
# Requirement already satisfied: six>=1.5 in /home/alessandro/tesi/tesi-python/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib->snntorch) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# # Import delle librerie

# %%
import numpy as np
import torch
import torch.nn as nn
import snntorch as snn
from snntorch import spikeplot as splt
from torch.utils.data import DataLoader
from torchvision import transforms
from torchvision import datasets
import matplotlib.pyplot as plt

# %% [markdown]
# # Batch size

# %%
batch_size = 512

# %% [markdown]
# # Dataset transformation

# %%
# Define a transform
transform = transforms.Compose([
    transforms.Resize((28, 28)),
    transforms.Grayscale(),
    transforms.ToTensor(),
    transforms.Normalize((0,), (1,))
])

# %%
# dataloader arguments
data_root='../data'

dtype = torch.float
device = torch.device("cuda") if torch.cuda.is_available() else torch.device("cpu")

# %% [markdown]
# # Datasets

# %%
# Datasets
mnist_train = datasets.MNIST(data_root, train=True, download=True, transform=transform)
mnist_test = datasets.MNIST(data_root, train=False, download=True, transform=transform)

# %% [markdown]
# # Dataloaders

# %%
# Create DataLoaders
train_loader = DataLoader(mnist_train, batch_size=batch_size, shuffle=True, drop_last=True)
test_loader = DataLoader(mnist_test, batch_size=batch_size, shuffle=True, drop_last=True)

# %%
"""
Utilities
"""
def plot_mem_rec(mem_rec, batch_size, targets):
    num_steps = len(mem_rec)
    for i in range(0,batch_size):
        fig = plt.figure()
        ax = fig.subplots()
        ax.set_xlim((-10,210))
        ax.set_ylim((-2,2))
        ss = mem_rec[:,i,:]
        plt.plot(range(0,num_steps), ss.cpu().detach())

        plt.title("Output Layer Membrane Output - {}".format(targets[i]))
        plt.xlabel("Time step")
        plt.ylabel("Neuron Number")
        fig.tight_layout()
    plt.show()


def plot_spk_rec(spk_rec, batch_size, targets):
    for i in range(0,batch_size):
        fig = plt.figure()
        ax = fig.subplots()
        ax.set_xlim((-10,210))
        ax.set_ylim((-1,11))
        ax.set_yticks(range(0,11))
        ss = spk_rec[:,i,:]
        splt.raster(ss, ax, s=1, c="black")

        plt.title("Output Layer - {}".format(targets[i]))
        plt.xlabel("Time step")
        plt.ylabel("Neuron Number")
        fig.tight_layout()
    plt.show()


def print_batch_accuracy(net, data, targets, train=False):
    output, _ = net(data.view(batch_size, -1))
    _, idx = output.sum(dim=0).max(1)
    acc = np.mean((targets == idx).detach().cpu().numpy())

    if train:
        print(f"Train set accuracy for a single minibatch: {acc*100:.2f}%")
    else:
        print(f"Test set accuracy for a single minibatch: {acc*100:.2f}%")

def train_printer():
    print(f"Epoch {epoch}, Iteration {iter_counter}")
    print(f"Train Set Loss: {loss_hist[counter]:.2f}")
    print(f"Test Set Loss: {test_loss_hist[counter]:.2f}")
    print_batch_accuracy(data, targets, train=True)
    print_batch_accuracy(test_data, test_targets, train=False)
    print("\n")

# %% [markdown]
# # Architettura e dinamica temporale

# %%
# Network Architecture
num_inputs = 28*28
num_hidden = 512
num_outputs = 10

# Temporal Dynamics
num_steps = 200
beta = 0.95

# %% [markdown]
# # Definizione della rete

# %%
# Define Network
class Net(nn.Module):
    def __init__(self):
        super().__init__()

        # Initialize layers
        self.fc1 = nn.Linear(num_inputs, num_hidden)
        self.lif1 = snn.Leaky(beta=beta)
        self.fc2 = nn.Linear(num_hidden, num_outputs)
        self.lif2 = snn.Leaky(beta=beta)

    def forward(self, x):

        # Initialize hidden states at t=0
        mem1 = self.lif1.init_leaky()
        mem2 = self.lif2.init_leaky()

        # Record the final layer
        spk2_rec = []
        mem2_rec = []

        for step in range(num_steps):
            cur1 = self.fc1(x)
            spk1, mem1 = self.lif1(cur1, mem1)
            cur2 = self.fc2(spk1)
            spk2, mem2 = self.lif2(cur2, mem2)
            spk2_rec.append(spk2)
            mem2_rec.append(mem2)

        return torch.stack(spk2_rec, dim=0), torch.stack(mem2_rec, dim=0)

# %% [markdown]
# # Creazione della rete

# %%
"""
Network instantiation
"""
net = Net().to(device=device)

# %%
# data, targets = next(iter(train_loader))
# print(data.size())
# print(targets.size())

# %%
# print(data.view(batch_size, -1).size())
# spk_rec, mem_rec = net(data.to(device).view(batch_size,-1))
# print(spk_rec.size())
# print(mem_rec.size())

# %%
# plot_spk_rec(spk_rec=spk_rec, batch_size=batch_size, targets=targets)

# %%
# plot_mem_rec(mem_rec=mem_rec, batch_size=batch_size, targets=targets)

# %%
# loss = nn.CrossEntropyLoss()
# optimizer = torch.optim.Adam(net.parameters(), lr=5e-4, betas=(0.9, 0.999))

# initialize the total loss value
# loss_val = torch.zeros((1), dtype=dtype, device=device)

# sum loss at every step
# for step in range(num_steps):
#   loss_val += loss(mem_rec[step], targets.to(device))

# print(loss_val)

# %%
# clear previously stored gradients
# optimizer.zero_grad()

# calculate the gradients
# loss_val.backward()

# weight update
# optimizer.step()

# %%
# data, targets = next(iter(train_loader))

# %%
# calculate new network outputs using the same data
# spk_rec, mem_rec = net(data.to(device).view(batch_size, -1))

# %%
# initialize the total loss value
# loss_val = torch.zeros((1), dtype=dtype, device=device)

# sum loss at every step
# for step in range(num_steps):
#   loss_val += loss(mem_rec[step], targets.to(device))

# %%
# plot_spk_rec(spk_rec=spk_rec,batch_size=batch_size,targets=targets)

# %%
# plot_mem_rec(mem_rec=mem_rec,batch_size=batch_size,targets=targets)

# %%
run_train = False
state_dict_file_path = "../models/snnTorch-MNIST-training.pt"

try:
    load_state_dict = torch.load( state_dict_file_path, map_location=device, )
    net.load_state_dict(load_state_dict)
except FileNotFoundError:
    print( "File not found running training" )
    run_train = True

if ( run_train == True ):
    num_epochs = 3
    loss_hist = []
    test_loss_hist = []
    counter = 0
    loss = nn.CrossEntropyLoss()
    optimizer = torch.optim.Adam(net.parameters(), lr=5e-4, betas=(0.9, 0.999))
    net.train()

    # Outer training loop
    for epoch in range(num_epochs):
        # Minibatch training loop
        for data, targets in train_loader:
            print( "Epoch ", epoch, " Iteration: ", counter)
            data = data.to(device)
            targets = targets.to(device)

            # forward pass
            optimizer.zero_grad()
            spk_rec, mem_rec = net(data.view(batch_size, -1))

            # initialize the loss & sum over time
            loss_val = torch.zeros((1), dtype=dtype, device=device)
            for step in range(num_steps):
                loss_val += loss(mem_rec[step], targets)
            print(loss_val)

            # Gradient calculation + weight update
            loss_val.backward()
            optimizer.step()

            # Store loss history for future plotting
            loss_hist.append(loss_val.item())
            counter += 1
            print_batch_accuracy(net, data, targets, train=True)

    torch.save( net.state_dict(), state_dict_file_path )
# Out:
# File not found running training
# Epoch  0  Iteration:  0
# tensor([512.0281], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 34.96%
# Epoch  0  Iteration:  1
# tensor([410.7221], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 55.66%
# Epoch  0  Iteration:  2
# tensor([372.0179], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 67.19%
# Epoch  0  Iteration:  3
# tensor([342.0449], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 71.48%
# Epoch  0  Iteration:  4
# tensor([329.8290], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 71.68%
# Epoch  0  Iteration:  5
# tensor([310.9658], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 74.41%
# Epoch  0  Iteration:  6
# tensor([297.1338], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 77.73%
# Epoch  0  Iteration:  7
# tensor([284.6687], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 78.71%
# Epoch  0  Iteration:  8
# tensor([267.2721], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 83.01%
# Epoch  0  Iteration:  9
# tensor([256.3770], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 82.62%
# Epoch  0  Iteration:  10
# tensor([243.6473], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 84.77%
# Epoch  0  Iteration:  11
# tensor([252.0176], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 80.27%
# Epoch  0  Iteration:  12
# tensor([226.7396], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 79.30%
# Epoch  0  Iteration:  13
# tensor([223.0191], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 83.40%
# Epoch  0  Iteration:  14
# tensor([226.4383], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 80.66%
# Epoch  0  Iteration:  15
# tensor([198.1030], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 82.62%
# Epoch  0  Iteration:  16
# tensor([197.5025], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 83.98%
# Epoch  0  Iteration:  17
# tensor([192.4630], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 83.01%
# Epoch  0  Iteration:  18
# tensor([184.6034], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 84.38%
# Epoch  0  Iteration:  19
# tensor([173.1389], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 83.79%
# Epoch  0  Iteration:  20
# tensor([168.3618], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 83.79%
# Epoch  0  Iteration:  21
# tensor([140.6490], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 88.28%
# Epoch  0  Iteration:  22
# tensor([194.3982], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 84.57%
# Epoch  0  Iteration:  23
# tensor([144.7268], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 86.13%
# Epoch  0  Iteration:  24
# tensor([156.1080], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 84.38%
# Epoch  0  Iteration:  25
# tensor([173.7183], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 84.96%
# Epoch  0  Iteration:  26
# tensor([178.9400], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 83.40%
# Epoch  0  Iteration:  27
# tensor([171.3014], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 85.55%
# Epoch  0  Iteration:  28
# tensor([161.1450], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 87.50%
# Epoch  0  Iteration:  29
# tensor([150.1685], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 84.77%
# Epoch  0  Iteration:  30
# tensor([180.2289], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 82.81%
# Epoch  0  Iteration:  31
# tensor([137.2227], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 87.50%
# Epoch  0  Iteration:  32
# tensor([140.9469], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 87.89%
# Epoch  0  Iteration:  33
# tensor([128.3918], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 87.70%
# Epoch  0  Iteration:  34
# tensor([146.6092], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 85.55%
# Epoch  0  Iteration:  35
# tensor([177.8548], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 83.01%
# Epoch  0  Iteration:  36
# tensor([170.0350], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 86.72%
# Epoch  0  Iteration:  37
# tensor([145.2063], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 87.50%
# Epoch  0  Iteration:  38
# tensor([147.5410], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 86.52%
# Epoch  0  Iteration:  39
# tensor([140.8479], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 89.06%
# Epoch  0  Iteration:  40
# tensor([148.8881], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 88.09%
# Epoch  0  Iteration:  41
# tensor([146.8046], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 86.72%
# Epoch  0  Iteration:  42
# tensor([175.8309], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 87.89%
# Epoch  0  Iteration:  43
# tensor([185.6232], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 85.74%
# Epoch  0  Iteration:  44
# tensor([176.3679], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 87.89%
# Epoch  0  Iteration:  45
# tensor([162.9431], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 85.94%
# Epoch  0  Iteration:  46
# tensor([139.6635], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 89.26%
# Epoch  0  Iteration:  47
# tensor([141.3502], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 85.35%
# Epoch  0  Iteration:  48
# tensor([178.0551], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 83.79%
# Epoch  0  Iteration:  49
# tensor([167.8903], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 85.55%
# Epoch  0  Iteration:  50
# tensor([157.4961], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 85.55%
# Epoch  0  Iteration:  51
# tensor([134.1962], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 87.89%
# Epoch  0  Iteration:  52
# tensor([129.3647], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 87.30%
# Epoch  0  Iteration:  53
# tensor([136.3680], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 89.26%
# Epoch  0  Iteration:  54
# tensor([158.3539], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 88.67%
# Epoch  0  Iteration:  55
# tensor([154.7247], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 85.35%
# Epoch  0  Iteration:  56
# tensor([134.6469], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 88.48%
# Epoch  0  Iteration:  57
# tensor([115.8140], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 89.45%
# Epoch  0  Iteration:  58
# tensor([142.9442], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 88.28%
# Epoch  0  Iteration:  59
# tensor([124.8796], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 87.89%
# Epoch  0  Iteration:  60
# tensor([101.0456], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 92.38%
# Epoch  0  Iteration:  61
# tensor([124.1623], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 89.65%
# Epoch  0  Iteration:  62
# tensor([150.0594], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 86.91%
# Epoch  0  Iteration:  63
# tensor([165.5182], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 89.26%
# Epoch  0  Iteration:  64
# tensor([143.9072], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 86.72%
# Epoch  0  Iteration:  65
# tensor([102.0869], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 89.65%
# Epoch  0  Iteration:  66
# tensor([125.6545], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 88.48%
# Epoch  0  Iteration:  67
# tensor([150.9523], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 88.28%
# Epoch  0  Iteration:  68
# tensor([147.9431], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 88.48%
# Epoch  0  Iteration:  69
# tensor([135.9073], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 88.09%
# Epoch  0  Iteration:  70
# tensor([126.8091], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 91.02%
# Epoch  0  Iteration:  71
# tensor([137.5356], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 88.87%
# Epoch  0  Iteration:  72
# tensor([139.8277], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 88.28%
# Epoch  0  Iteration:  73
# tensor([138.0046], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 87.11%
# Epoch  0  Iteration:  74
# tensor([121.0808], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 91.41%
# Epoch  0  Iteration:  75
# tensor([112.0091], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 89.84%
# Epoch  0  Iteration:  76
# tensor([107.3774], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 89.65%
# Epoch  0  Iteration:  77
# tensor([103.0690], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 89.26%
# Epoch  0  Iteration:  78
# tensor([120.9277], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 90.43%
# Epoch  0  Iteration:  79
# tensor([109.4673], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 89.65%
# Epoch  0  Iteration:  80
# tensor([151.1292], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 87.89%
# Epoch  0  Iteration:  81
# tensor([142.1444], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 88.28%
# Epoch  0  Iteration:  82
# tensor([159.1105], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 87.11%
# Epoch  0  Iteration:  83
# tensor([175.1297], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 87.50%
# Epoch  0  Iteration:  84
# tensor([138.6507], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 89.06%
# Epoch  0  Iteration:  85
# tensor([125.2909], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 89.45%
# Epoch  0  Iteration:  86
# tensor([113.0407], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 90.04%
# Epoch  0  Iteration:  87
# tensor([116.1931], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 91.21%
# Epoch  0  Iteration:  88
# tensor([111.7639], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 90.43%
# Epoch  0  Iteration:  89
# tensor([108.9318], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 88.09%
# Epoch  0  Iteration:  90
# tensor([100.1369], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 90.62%
# Epoch  0  Iteration:  91
# tensor([140.3309], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 88.48%
# Epoch  0  Iteration:  92
# tensor([104.9916], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 91.02%
# Epoch  0  Iteration:  93
# tensor([129.6329], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 89.84%
# Epoch  0  Iteration:  94
# tensor([102.6732], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 89.26%
# Epoch  0  Iteration:  95
# tensor([95.7041], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 90.04%
# Epoch  0  Iteration:  96
# tensor([92.8560], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 90.43%
# Epoch  0  Iteration:  97
# tensor([111.3542], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 91.21%
# Epoch  0  Iteration:  98
# tensor([118.0666], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 88.28%
# Epoch  0  Iteration:  99
# tensor([155.2560], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 87.70%
# Epoch  0  Iteration:  100
# tensor([135.0851], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 88.28%
# Epoch  0  Iteration:  101
# tensor([110.5238], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 90.62%
# Epoch  0  Iteration:  102
# tensor([103.6788], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 91.80%
# Epoch  0  Iteration:  103
# tensor([110.7738], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 90.82%
# Epoch  0  Iteration:  104
# tensor([87.6738], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 92.58%
# Epoch  0  Iteration:  105
# tensor([94.4811], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 92.77%
# Epoch  0  Iteration:  106
# tensor([99.3357], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 90.04%
# Epoch  0  Iteration:  107
# tensor([112.1734], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 92.19%
# Epoch  0  Iteration:  108
# tensor([125.3913], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 89.65%
# Epoch  0  Iteration:  109
# tensor([164.8451], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 87.11%
# Epoch  0  Iteration:  110
# tensor([143.3490], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 90.62%
# Epoch  0  Iteration:  111
# tensor([72.4364], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 92.38%
# Epoch  0  Iteration:  112
# tensor([109.3246], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 88.87%
# Epoch  0  Iteration:  113
# tensor([149.2501], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 87.50%
# Epoch  0  Iteration:  114
# tensor([138.3739], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 89.06%
# Epoch  0  Iteration:  115
# tensor([94.5525], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 90.82%
# Epoch  0  Iteration:  116
# tensor([92.1357], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 90.23%
# Epoch  1  Iteration:  117
# tensor([91.2096], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 90.82%
# Epoch  1  Iteration:  118
# tensor([126.0486], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 89.45%
# Epoch  1  Iteration:  119
# tensor([113.3039], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 90.82%
# Epoch  1  Iteration:  120
# tensor([142.8536], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 88.48%
# Epoch  1  Iteration:  121
# tensor([75.6505], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 91.99%
# Epoch  1  Iteration:  122
# tensor([73.1400], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 92.19%
# Epoch  1  Iteration:  123
# tensor([97.9748], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 91.41%
# Epoch  1  Iteration:  124
# tensor([103.0377], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 91.99%
# Epoch  1  Iteration:  125
# tensor([100.8052], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 91.21%
# Epoch  1  Iteration:  126
# tensor([90.0341], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 89.84%
# Epoch  1  Iteration:  127
# tensor([80.2291], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 93.75%
# Epoch  1  Iteration:  128
# tensor([86.7434], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 92.38%
# Epoch  1  Iteration:  129
# tensor([106.6200], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 90.43%
# Epoch  1  Iteration:  130
# tensor([112.4793], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 91.60%
# Epoch  1  Iteration:  131
# tensor([93.8830], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 89.84%
# Epoch  1  Iteration:  132
# tensor([81.3763], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 91.60%
# Epoch  1  Iteration:  133
# tensor([132.6553], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 90.62%
# Epoch  1  Iteration:  134
# tensor([90.8819], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 92.77%
# Epoch  1  Iteration:  135
# tensor([111.9774], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 88.09%
# Epoch  1  Iteration:  136
# tensor([114.0034], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 91.60%
# Epoch  1  Iteration:  137
# tensor([79.4763], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 90.82%
# Epoch  1  Iteration:  138
# tensor([112.6872], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 91.41%
# Epoch  1  Iteration:  139
# tensor([97.9648], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 92.38%
# Epoch  1  Iteration:  140
# tensor([112.6647], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 90.62%
# Epoch  1  Iteration:  141
# tensor([115.4043], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 89.45%
# Epoch  1  Iteration:  142
# tensor([90.9107], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 91.02%
# Epoch  1  Iteration:  143
# tensor([107.3427], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 90.43%
# Epoch  1  Iteration:  144
# tensor([81.2523], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 92.38%
# Epoch  1  Iteration:  145
# tensor([89.7368], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 91.80%
# Epoch  1  Iteration:  146
# tensor([93.5465], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 91.80%
# Epoch  1  Iteration:  147
# tensor([93.8750], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 92.19%
# Epoch  1  Iteration:  148
# tensor([87.0917], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 91.41%
# Epoch  1  Iteration:  149
# tensor([83.7435], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 92.77%
# Epoch  1  Iteration:  150
# tensor([97.6971], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 91.60%
# Epoch  1  Iteration:  151
# tensor([89.7452], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 91.99%
# Epoch  1  Iteration:  152
# tensor([81.3712], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 92.38%
# Epoch  1  Iteration:  153
# tensor([89.4617], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 91.41%
# Epoch  1  Iteration:  154
# tensor([115.8770], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 89.84%
# Epoch  1  Iteration:  155
# tensor([102.8514], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 88.67%
# Epoch  1  Iteration:  156
# tensor([94.7402], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 89.45%
# Epoch  1  Iteration:  157
# tensor([126.4886], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 90.23%
# Epoch  1  Iteration:  158
# tensor([95.6853], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 89.26%
# Epoch  1  Iteration:  159
# tensor([120.9676], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 90.23%
# Epoch  1  Iteration:  160
# tensor([98.7585], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 90.62%
# Epoch  1  Iteration:  161
# tensor([100.0137], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 90.82%
# Epoch  1  Iteration:  162
# tensor([89.4937], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 90.04%
# Epoch  1  Iteration:  163
# tensor([81.1495], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 91.60%
# Epoch  1  Iteration:  164
# tensor([100.3883], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 89.45%
# Epoch  1  Iteration:  165
# tensor([94.1775], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 92.97%
# Epoch  1  Iteration:  166
# tensor([123.6911], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 90.82%
# Epoch  1  Iteration:  167
# tensor([84.4020], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 91.60%
# Epoch  1  Iteration:  168
# tensor([84.5664], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 90.43%
# Epoch  1  Iteration:  169
# tensor([85.0389], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 93.36%
# Epoch  1  Iteration:  170
# tensor([102.4375], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 90.43%
# Epoch  1  Iteration:  171
# tensor([83.3595], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 92.38%
# Epoch  1  Iteration:  172
# tensor([115.8295], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 90.23%
# Epoch  1  Iteration:  173
# tensor([96.0161], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 91.80%
# Epoch  1  Iteration:  174
# tensor([87.3413], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 91.21%
# Epoch  1  Iteration:  175
# tensor([154.7419], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 89.06%
# Epoch  1  Iteration:  176
# tensor([116.9016], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 90.62%
# Epoch  1  Iteration:  177
# tensor([104.8313], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 90.82%
# Epoch  1  Iteration:  178
# tensor([98.4476], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 86.72%
# Epoch  1  Iteration:  179
# tensor([112.4956], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 90.04%
# Epoch  1  Iteration:  180
# tensor([76.4639], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 91.99%
# Epoch  1  Iteration:  181
# tensor([91.1827], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 89.65%
# Epoch  1  Iteration:  182
# tensor([88.8189], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 93.75%
# Epoch  1  Iteration:  183
# tensor([102.6741], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 89.26%
# Epoch  1  Iteration:  184
# tensor([72.8799], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 91.60%
# Epoch  1  Iteration:  185
# tensor([81.3024], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 90.04%
# Epoch  1  Iteration:  186
# tensor([71.6378], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 90.62%
# Epoch  1  Iteration:  187
# tensor([102.6961], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 89.06%
# Epoch  1  Iteration:  188
# tensor([112.1770], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 90.62%
# Epoch  1  Iteration:  189
# tensor([84.3173], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 91.41%
# Epoch  1  Iteration:  190
# tensor([74.3858], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 91.21%
# Epoch  1  Iteration:  191
# tensor([92.4620], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 90.43%
# Epoch  1  Iteration:  192
# tensor([78.7229], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 91.41%
# Epoch  1  Iteration:  193
# tensor([93.4022], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 90.23%
# Epoch  1  Iteration:  194
# tensor([61.9256], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 92.77%
# Epoch  1  Iteration:  195
# tensor([76.2507], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 91.60%
# Epoch  1  Iteration:  196
# tensor([82.0109], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 90.62%
# Epoch  1  Iteration:  197
# tensor([80.3475], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 91.99%
# Epoch  1  Iteration:  198
# tensor([91.4482], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 91.60%
# Epoch  1  Iteration:  199
# tensor([102.4782], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 91.60%
# Epoch  1  Iteration:  200
# tensor([91.2834], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 87.70%
# Epoch  1  Iteration:  201
# tensor([53.3564], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 93.55%
# Epoch  1  Iteration:  202
# tensor([84.4955], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 90.62%
# Epoch  1  Iteration:  203
# tensor([80.3758], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 90.04%
# Epoch  1  Iteration:  204
# tensor([82.7497], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 91.99%
# Epoch  1  Iteration:  205
# tensor([83.3593], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 90.43%
# Epoch  1  Iteration:  206
# tensor([65.7284], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 92.19%
# Epoch  1  Iteration:  207
# tensor([108.9109], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 89.45%
# Epoch  1  Iteration:  208
# tensor([89.5611], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 92.19%
# Epoch  1  Iteration:  209
# tensor([110.9887], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 90.23%
# Epoch  1  Iteration:  210
# tensor([99.3127], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 90.62%
# Epoch  1  Iteration:  211
# tensor([82.6791], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 93.75%
# Epoch  1  Iteration:  212
# tensor([113.5154], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 91.99%
# Epoch  1  Iteration:  213
# tensor([104.5431], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 90.04%
# Epoch  1  Iteration:  214
# tensor([102.9125], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 90.43%
# Epoch  1  Iteration:  215
# tensor([79.2521], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 91.41%
# Epoch  1  Iteration:  216
# tensor([94.1108], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 88.67%
# Epoch  1  Iteration:  217
# tensor([101.4880], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 91.41%
# Epoch  1  Iteration:  218
# tensor([77.1840], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 90.62%
# Epoch  1  Iteration:  219
# tensor([57.6982], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 93.95%
# Epoch  1  Iteration:  220
# tensor([83.8241], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 90.82%
# Epoch  1  Iteration:  221
# tensor([99.9580], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 91.80%
# Epoch  1  Iteration:  222
# tensor([69.1160], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 89.84%
# Epoch  1  Iteration:  223
# tensor([83.3402], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 92.19%
# Epoch  1  Iteration:  224
# tensor([119.6000], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 91.21%
# Epoch  1  Iteration:  225
# tensor([81.4657], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 91.21%
# Epoch  1  Iteration:  226
# tensor([104.3802], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 90.04%
# Epoch  1  Iteration:  227
# tensor([81.1453], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 91.60%
# Epoch  1  Iteration:  228
# tensor([82.3518], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 91.60%
# Epoch  1  Iteration:  229
# tensor([97.6599], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 90.23%
# Epoch  1  Iteration:  230
# tensor([77.3184], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 92.77%
# Epoch  1  Iteration:  231
# tensor([84.0519], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 90.82%
# Epoch  1  Iteration:  232
# tensor([114.7491], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 90.04%
# Epoch  1  Iteration:  233
# tensor([109.4730], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 90.62%
# Epoch  2  Iteration:  234
# tensor([88.3365], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 89.65%
# Epoch  2  Iteration:  235
# tensor([62.3488], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 92.77%
# Epoch  2  Iteration:  236
# tensor([84.8041], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 89.65%
# Epoch  2  Iteration:  237
# tensor([58.8539], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 91.99%
# Epoch  2  Iteration:  238
# tensor([65.1951], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 90.62%
# Epoch  2  Iteration:  239
# tensor([100.3034], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 89.06%
# Epoch  2  Iteration:  240
# tensor([108.6202], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 89.06%
# Epoch  2  Iteration:  241
# tensor([68.8880], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 93.36%
# Epoch  2  Iteration:  242
# tensor([103.6782], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 91.21%
# Epoch  2  Iteration:  243
# tensor([93.1319], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 91.60%
# Epoch  2  Iteration:  244
# tensor([85.8953], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 91.21%
# Epoch  2  Iteration:  245
# tensor([96.6720], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 91.02%
# Epoch  2  Iteration:  246
# tensor([86.4219], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 90.62%
# Epoch  2  Iteration:  247
# tensor([90.8772], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 89.45%
# Epoch  2  Iteration:  248
# tensor([178.3866], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 88.67%
# Epoch  2  Iteration:  249
# tensor([57.9007], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 92.97%
# Epoch  2  Iteration:  250
# tensor([96.3237], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 89.84%
# Epoch  2  Iteration:  251
# tensor([101.1128], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 90.04%
# Epoch  2  Iteration:  252
# tensor([63.7817], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 91.60%
# Epoch  2  Iteration:  253
# tensor([114.9409], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 88.87%
# Epoch  2  Iteration:  254
# tensor([74.6041], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 92.19%
# Epoch  2  Iteration:  255
# tensor([88.2107], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 90.23%
# Epoch  2  Iteration:  256
# tensor([105.0401], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 91.60%
# Epoch  2  Iteration:  257
# tensor([53.6513], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 92.58%
# Epoch  2  Iteration:  258
# tensor([87.7525], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 92.38%
# Epoch  2  Iteration:  259
# tensor([76.3754], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 91.02%
# Epoch  2  Iteration:  260
# tensor([102.4160], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 89.65%
# Epoch  2  Iteration:  261
# tensor([75.7762], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 90.23%
# Epoch  2  Iteration:  262
# tensor([82.1278], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 90.23%
# Epoch  2  Iteration:  263
# tensor([92.5141], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 89.26%
# Epoch  2  Iteration:  264
# tensor([82.9644], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 89.84%
# Epoch  2  Iteration:  265
# tensor([60.5692], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 92.38%
# Epoch  2  Iteration:  266
# tensor([66.8928], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 92.58%
# Epoch  2  Iteration:  267
# tensor([74.2259], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 91.80%
# Epoch  2  Iteration:  268
# tensor([109.0798], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 90.62%
# Epoch  2  Iteration:  269
# tensor([69.8009], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 91.80%
# Epoch  2  Iteration:  270
# tensor([70.1105], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 91.02%
# Epoch  2  Iteration:  271
# tensor([61.5099], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 93.55%
# Epoch  2  Iteration:  272
# tensor([47.7825], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 93.55%
# Epoch  2  Iteration:  273
# tensor([69.9400], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 90.82%
# Epoch  2  Iteration:  274
# tensor([108.7732], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 90.62%
# Epoch  2  Iteration:  275
# tensor([80.7270], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 91.21%
# Epoch  2  Iteration:  276
# tensor([97.6643], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 88.28%
# Epoch  2  Iteration:  277
# tensor([62.4931], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 91.80%
# Epoch  2  Iteration:  278
# tensor([86.3106], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 90.82%
# Epoch  2  Iteration:  279
# tensor([110.7917], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 88.87%
# Epoch  2  Iteration:  280
# tensor([85.9994], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 89.45%
# Epoch  2  Iteration:  281
# tensor([75.1836], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 91.02%
# Epoch  2  Iteration:  282
# tensor([87.3968], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 91.80%
# Epoch  2  Iteration:  283
# tensor([72.6385], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 90.04%
# Epoch  2  Iteration:  284
# tensor([68.5911], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 93.16%
# Epoch  2  Iteration:  285
# tensor([119.2915], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 88.28%
# Epoch  2  Iteration:  286
# tensor([53.0233], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 90.82%
# Epoch  2  Iteration:  287
# tensor([73.7162], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 91.80%
# Epoch  2  Iteration:  288
# tensor([90.9158], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 92.38%
# Epoch  2  Iteration:  289
# tensor([86.3377], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 91.21%
# Epoch  2  Iteration:  290
# tensor([69.6912], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 90.82%
# Epoch  2  Iteration:  291
# tensor([62.3232], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 92.77%
# Epoch  2  Iteration:  292
# tensor([87.8063], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 88.67%
# Epoch  2  Iteration:  293
# tensor([89.5138], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 90.23%
# Epoch  2  Iteration:  294
# tensor([89.0178], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 89.84%
# Epoch  2  Iteration:  295
# tensor([82.7473], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 89.84%
# Epoch  2  Iteration:  296
# tensor([70.7806], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 90.62%
# Epoch  2  Iteration:  297
# tensor([80.3526], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 92.77%
# Epoch  2  Iteration:  298
# tensor([64.1053], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 91.60%
# Epoch  2  Iteration:  299
# tensor([77.2963], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 93.55%
# Epoch  2  Iteration:  300
# tensor([101.1037], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 90.62%
# Epoch  2  Iteration:  301
# tensor([86.0371], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 92.38%
# Epoch  2  Iteration:  302
# tensor([124.0038], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 90.62%
# Epoch  2  Iteration:  303
# tensor([62.8329], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 91.41%
# Epoch  2  Iteration:  304
# tensor([58.0377], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 91.41%
# Epoch  2  Iteration:  305
# tensor([87.1643], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 91.80%
# Epoch  2  Iteration:  306
# tensor([100.6869], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 90.23%
# Epoch  2  Iteration:  307
# tensor([63.8992], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 91.02%
# Epoch  2  Iteration:  308
# tensor([84.9749], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 88.28%
# Epoch  2  Iteration:  309
# tensor([57.2175], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 91.41%
# Epoch  2  Iteration:  310
# tensor([54.5440], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 92.58%
# Epoch  2  Iteration:  311
# tensor([74.5983], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 89.65%
# Epoch  2  Iteration:  312
# tensor([84.6471], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 92.77%
# Epoch  2  Iteration:  313
# tensor([112.9259], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 88.09%
# Epoch  2  Iteration:  314
# tensor([82.8456], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 89.45%
# Epoch  2  Iteration:  315
# tensor([78.3016], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 89.06%
# Epoch  2  Iteration:  316
# tensor([93.8540], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 89.26%
# Epoch  2  Iteration:  317
# tensor([79.5155], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 90.04%
# Epoch  2  Iteration:  318
# tensor([93.4189], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 90.04%
# Epoch  2  Iteration:  319
# tensor([91.9184], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 89.65%
# Epoch  2  Iteration:  320
# tensor([144.0806], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 86.72%
# Epoch  2  Iteration:  321
# tensor([64.2142], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 93.36%
# Epoch  2  Iteration:  322
# tensor([57.9021], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 94.14%
# Epoch  2  Iteration:  323
# tensor([75.8380], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 90.82%
# Epoch  2  Iteration:  324
# tensor([77.0044], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 88.09%
# Epoch  2  Iteration:  325
# tensor([86.6656], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 90.62%
# Epoch  2  Iteration:  326
# tensor([66.7007], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 90.82%
# Epoch  2  Iteration:  327
# tensor([65.6036], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 89.65%
# Epoch  2  Iteration:  328
# tensor([75.4822], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 91.41%
# Epoch  2  Iteration:  329
# tensor([78.7994], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 90.04%
# Epoch  2  Iteration:  330
# tensor([80.2675], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 91.02%
# Epoch  2  Iteration:  331
# tensor([81.7859], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 91.80%
# Epoch  2  Iteration:  332
# tensor([80.6851], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 91.02%
# Epoch  2  Iteration:  333
# tensor([70.4184], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 92.38%
# Epoch  2  Iteration:  334
# tensor([62.0527], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 90.23%
# Epoch  2  Iteration:  335
# tensor([60.6614], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 92.38%
# Epoch  2  Iteration:  336
# tensor([74.9148], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 91.60%
# Epoch  2  Iteration:  337
# tensor([62.1998], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 92.58%
# Epoch  2  Iteration:  338
# tensor([86.4154], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 89.84%
# Epoch  2  Iteration:  339
# tensor([63.9210], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 91.21%
# Epoch  2  Iteration:  340
# tensor([85.5180], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 92.58%
# Epoch  2  Iteration:  341
# tensor([62.5782], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 92.19%
# Epoch  2  Iteration:  342
# tensor([90.4528], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 91.60%
# Epoch  2  Iteration:  343
# tensor([73.3921], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 91.21%
# Epoch  2  Iteration:  344
# tensor([92.4300], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 91.80%
# Epoch  2  Iteration:  345
# tensor([55.5683], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 92.97%
# Epoch  2  Iteration:  346
# tensor([86.1809], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 92.97%
# Epoch  2  Iteration:  347
# tensor([106.3697], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 90.62%
# Epoch  2  Iteration:  348
# tensor([68.3335], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 91.21%
# Epoch  2  Iteration:  349
# tensor([73.8849], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 91.21%
# Epoch  2  Iteration:  350
# tensor([69.5042], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 92.58%

# %%
# Test set
with torch.no_grad():
    net.eval()

    for test_data, test_targets in test_loader: 
        test_data = test_data.to(device)
        test_targets = test_targets.to(device)

        # Test set forward pass
        test_spk, test_mem = net(test_data.view(batch_size, -1))

        # Test set loss
        test_loss = torch.zeros((1), dtype=dtype, device=device)
        for step in range(num_steps):
            test_loss += loss(test_mem[step], test_targets)
        test_loss_hist.append(test_loss.item())

        # Print train/test loss/accuracy
        print_batch_accuracy(net, test_data, test_targets)
# Out:
# Test set accuracy for a single minibatch: 91.21%
# Test set accuracy for a single minibatch: 92.19%
# Test set accuracy for a single minibatch: 88.87%
# Test set accuracy for a single minibatch: 92.38%
# Test set accuracy for a single minibatch: 91.02%
# Test set accuracy for a single minibatch: 90.23%
# Test set accuracy for a single minibatch: 92.38%
# Test set accuracy for a single minibatch: 90.62%
# Test set accuracy for a single minibatch: 89.84%
# Test set accuracy for a single minibatch: 89.84%
# Test set accuracy for a single minibatch: 92.77%
# Test set accuracy for a single minibatch: 92.97%
# Test set accuracy for a single minibatch: 93.16%
# Test set accuracy for a single minibatch: 91.02%
# Test set accuracy for a single minibatch: 92.58%
# Test set accuracy for a single minibatch: 92.19%
# Test set accuracy for a single minibatch: 91.80%
# Test set accuracy for a single minibatch: 90.62%
# Test set accuracy for a single minibatch: 91.80%

# %%
print(loss_hist)
print(test_loss_hist)
# Out:
# [512.028076171875, 410.7221374511719, 372.0179138183594, 342.04486083984375, 329.82904052734375, 310.96575927734375, 297.1337890625, 284.6686706542969, 267.2720642089844, 256.3770446777344, 243.6473388671875, 252.01756286621094, 226.73963928222656, 223.0190887451172, 226.4382781982422, 198.10301208496094, 197.50254821777344, 192.46295166015625, 184.60342407226562, 173.13893127441406, 168.36184692382812, 140.64895629882812, 194.39822387695312, 144.7267608642578, 156.1080322265625, 173.71832275390625, 178.94004821777344, 171.3014373779297, 161.14501953125, 150.16848754882812, 180.2289276123047, 137.2227020263672, 140.94688415527344, 128.3917694091797, 146.60923767089844, 177.85475158691406, 170.03500366210938, 145.20632934570312, 147.54104614257812, 140.8478546142578, 148.88809204101562, 146.8045654296875, 175.8308868408203, 185.62318420410156, 176.36788940429688, 162.9430694580078, 139.6634521484375, 141.3501739501953, 178.05508422851562, 167.8902587890625, 157.4961395263672, 134.19618225097656, 129.36468505859375, 136.36802673339844, 158.35394287109375, 154.72474670410156, 134.64691162109375, 115.81404113769531, 142.94415283203125, 124.87960052490234, 101.04563903808594, 124.16228485107422, 150.0593719482422, 165.51824951171875, 143.90716552734375, 102.08686065673828, 125.65447998046875, 150.9522705078125, 147.94309997558594, 135.9073028564453, 126.80913543701172, 137.53562927246094, 139.82774353027344, 138.0045928955078, 121.08079528808594, 112.00908660888672, 107.3774185180664, 103.06903839111328, 120.92774200439453, 109.46733093261719, 151.1292266845703, 142.1444091796875, 159.11050415039062, 175.1297149658203, 138.6506805419922, 125.29090881347656, 113.04067993164062, 116.1931381225586, 111.7639389038086, 108.93177795410156, 100.13688659667969, 140.3308868408203, 104.99158477783203, 129.63290405273438, 102.67324829101562, 95.7040786743164, 92.85597229003906, 111.35416412353516, 118.06664276123047, 155.25595092773438, 135.08505249023438, 110.52379608154297, 103.67877960205078, 110.7738265991211, 87.673828125, 94.4810791015625, 99.335693359375, 112.1733627319336, 125.39129638671875, 164.8451385498047, 143.34902954101562, 72.43643951416016, 109.3245849609375, 149.2501220703125, 138.3739471435547, 94.55249786376953, 92.13571166992188, 91.20964813232422, 126.04862213134766, 113.30387878417969, 142.8536376953125, 75.65052032470703, 73.1400146484375, 97.97481536865234, 103.0377197265625, 100.80524444580078, 90.03414154052734, 80.2291030883789, 86.74344635009766, 106.61996459960938, 112.47933197021484, 93.8830337524414, 81.3763198852539, 132.6552734375, 90.88188171386719, 111.97744750976562, 114.00340270996094, 79.47634887695312, 112.68720245361328, 97.96481323242188, 112.66468811035156, 115.40428924560547, 90.91071319580078, 107.34266662597656, 81.25225067138672, 89.73682403564453, 93.54649353027344, 93.87503051757812, 87.09173583984375, 83.7435073852539, 97.69713592529297, 89.74516296386719, 81.37115478515625, 89.46168518066406, 115.87702941894531, 102.85140991210938, 94.74015808105469, 126.48857116699219, 95.68525695800781, 120.96759796142578, 98.75849151611328, 100.01370239257812, 89.49372100830078, 81.14945220947266, 100.38829040527344, 94.17748260498047, 123.69110107421875, 84.40199279785156, 84.56636047363281, 85.03885650634766, 102.43753814697266, 83.35945892333984, 115.82947540283203, 96.01606750488281, 87.34130096435547, 154.74185180664062, 116.90158081054688, 104.83128356933594, 98.44759368896484, 112.49559020996094, 76.4638671875, 91.18270111083984, 88.81889343261719, 102.6740951538086, 72.8798828125, 81.30236053466797, 71.6377944946289, 102.69612884521484, 112.17700958251953, 84.31732940673828, 74.38578033447266, 92.46195220947266, 78.72290802001953, 93.40219116210938, 61.92557907104492, 76.2507095336914, 82.01089477539062, 80.3475341796875, 91.44815063476562, 102.47816467285156, 91.28337860107422, 53.35636901855469, 84.4954605102539, 80.37577819824219, 82.74974060058594, 83.35929107666016, 65.72836303710938, 108.9108 ...
# [73.04986572265625, 65.31348419189453, 80.22122192382812, 53.72156524658203, 84.02142333984375, 93.01377868652344, 57.00636672973633, 83.18087768554688, 84.21540069580078, 86.68248748779297, 68.18758392333984, 39.95417785644531, 57.752132415771484, 94.48086547851562, 79.91857147216797, 67.03434753417969, 87.45166015625, 77.86235809326172, 88.21836853027344]

# %%
total = 0
correct = 0

# drop_last switched to False to keep all samples
test_loader = DataLoader(mnist_test, batch_size=batch_size, shuffle=True, drop_last=False)

with torch.no_grad():
  net.eval()
  for data, targets in test_loader:
    data = data.to(device)
    targets = targets.to(device)

    # forward pass
    test_spk, _ = net(data.view(data.size(0), -1))

    # calculate total accuracy
    _, predicted = test_spk.sum(dim=0).max(1)
    total += targets.size(0)
    correct += (predicted == targets).sum().item()

# %%
print(total)
print(correct)
print("{:.2f}".format(100*(correct/total)))
# Out:
# 10000
# 9143
# 91.43
