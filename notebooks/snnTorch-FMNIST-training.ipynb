# %% [markdown]
# # Import librerie

# %%
import numpy as np
import torch
import torch.nn as nn
import snntorch as snn
from snntorch import spikeplot as splt
from torch.utils.data import DataLoader
from torchvision import transforms
from torchvision import datasets
import matplotlib.pyplot as plt

# %% [markdown]
# # Batch size

# %%
batch_size = 512

# %% [markdown]
# # Dataset transformation

# %%
# Define a transform
transform = transforms.Compose([
    transforms.Resize((28, 28)),
    transforms.Grayscale(),
    transforms.ToTensor(),
    transforms.Normalize((0,), (1,))
])

# %%
# dataloader arguments
data_root='../data'

dtype = torch.float
device = torch.device("cuda") if torch.cuda.is_available() else torch.device("cpu")

# %% [markdown]
# # Datasets

# %%
fmnist_train = datasets.FashionMNIST(data_root, train=True, download=True, transform=transform)
fmnist_test = datasets.FashionMNIST(data_root, train=False, download=True, transform=transform)

# %% [markdown]
# # Dataloaders

# %%
# Create DataLoaders
train_loader = DataLoader(fmnist_train, batch_size=batch_size, shuffle=True, drop_last=True)
test_loader = DataLoader(fmnist_test, batch_size=batch_size, shuffle=True, drop_last=True)

# %%
"""
Utilities
"""
def plot_mem_rec(mem_rec, batch_size, targets):
    num_steps = len(mem_rec)
    for i in range(0,batch_size):
        fig = plt.figure()
        ax = fig.subplots()
        ax.set_xlim((-10,210))
        ax.set_ylim((-2,2))
        ss = mem_rec[:,i,:]
        plt.plot(range(0,num_steps), ss.cpu().detach())

        plt.title("Output Layer Membrane Output - {}".format(targets[i]))
        plt.xlabel("Time step")
        plt.ylabel("Neuron Number")
        fig.tight_layout()
    plt.show()


def plot_spk_rec(spk_rec, batch_size, targets):
    for i in range(0,batch_size):
        fig = plt.figure()
        ax = fig.subplots()
        ax.set_xlim((-10,210))
        ax.set_ylim((-1,11))
        ax.set_yticks(range(0,11))
        ss = spk_rec[:,i,:]
        splt.raster(ss, ax, s=1, c="black")

        plt.title("Output Layer - {}".format(targets[i]))
        plt.xlabel("Time step")
        plt.ylabel("Neuron Number")
        fig.tight_layout()
    plt.show()


def print_batch_accuracy(net, data, targets, train=False):
    output, _ = net(data.view(batch_size, -1))
    _, idx = output.sum(dim=0).max(1)
    acc = np.mean((targets == idx).detach().cpu().numpy())

    if train:
        print(f"Train set accuracy for a single minibatch: {acc*100:.2f}%")
    else:
        print(f"Test set accuracy for a single minibatch: {acc*100:.2f}%")

def train_printer():
    print(f"Epoch {epoch}, Iteration {iter_counter}")
    print(f"Train Set Loss: {loss_hist[counter]:.2f}")
    print(f"Test Set Loss: {test_loss_hist[counter]:.2f}")
    print_batch_accuracy(data, targets, train=True)
    print_batch_accuracy(test_data, test_targets, train=False)
    print("\n")

# %% [markdown]
# # Architettura e dinamica temporale

# %%
# Network Architecture
num_inputs = 28*28
num_hidden = 512
num_outputs = 10

# Temporal Dynamics
num_steps = 200
beta = 0.95

# %% [markdown]
# # Definizione della rete

# %%
# Define Network
class Net(nn.Module):
    def __init__(self):
        super().__init__()

        # Initialize layers
        self.fc1 = nn.Linear(num_inputs, num_hidden)
        self.lif1 = snn.Leaky(beta=beta)
        self.fc2 = nn.Linear(num_hidden, num_outputs)
        self.lif2 = snn.Leaky(beta=beta)

    def forward(self, x):

        # Initialize hidden states at t=0
        mem1 = self.lif1.init_leaky()
        mem2 = self.lif2.init_leaky()

        # Record the final layer
        spk2_rec = []
        mem2_rec = []

        for step in range(num_steps):
            cur1 = self.fc1(x)
            spk1, mem1 = self.lif1(cur1, mem1)
            cur2 = self.fc2(spk1)
            spk2, mem2 = self.lif2(cur2, mem2)
            spk2_rec.append(spk2)
            mem2_rec.append(mem2)

        return torch.stack(spk2_rec, dim=0), torch.stack(mem2_rec, dim=0)

# %% [markdown]
# # Creazione della rete

# %%
"""
Network instantiation
"""
net = Net().to(device=device)

# %%
# data, targets = next(iter(train_loader))
# print(data.size())
# print(targets.size())

# %%
# print(data.view(batch_size, -1).size())
# spk_rec, mem_rec = net(data.to(device).view(batch_size,-1))
# print(spk_rec.size())
# print(mem_rec.size())

# %%
# plot_spk_rec(spk_rec=spk_rec, batch_size=batch_size, targets=targets)

# %%
# plot_mem_rec(mem_rec=mem_rec, batch_size=batch_size, targets=targets)

# %%
# loss = nn.CrossEntropyLoss()
# optimizer = torch.optim.Adam(net.parameters(), lr=5e-4, betas=(0.9, 0.999))

# initialize the total loss value
# loss_val = torch.zeros((1), dtype=dtype, device=device)

# sum loss at every step
# for step in range(num_steps):
#   loss_val += loss(mem_rec[step], targets.to(device))

# print(loss_val)

# %%
# clear previously stored gradients
# optimizer.zero_grad()

# calculate the gradients
# loss_val.backward()

# weight update
# optimizer.step()

# %%
# data, targets = next(iter(train_loader))

# %%
# calculate new network outputs using the same data
# spk_rec, mem_rec = net(data.to(device).view(batch_size, -1))

# %%
# initialize the total loss value
# loss_val = torch.zeros((1), dtype=dtype, device=device)

# sum loss at every step
# for step in range(num_steps):
#   loss_val += loss(mem_rec[step], targets.to(device))

# %%
# plot_spk_rec(spk_rec=spk_rec,batch_size=batch_size,targets=targets)

# %%
# plot_mem_rec(mem_rec=mem_rec,batch_size=batch_size,targets=targets)

# %%
num_epochs = 3
loss_hist = []
test_loss_hist = []
counter = 0
loss = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(net.parameters(), lr=5e-4, betas=(0.9, 0.999))
net.train()


# Outer training loop
for epoch in range(num_epochs):
    # Minibatch training loop
    for data, targets in train_loader:
        print( "Epoch ", epoch, " Iteration: ", counter)
        data = data.to(device)
        targets = targets.to(device)

        # forward pass
        optimizer.zero_grad()
        spk_rec, mem_rec = net(data.view(batch_size, -1))

        # initialize the loss & sum over time
        loss_val = torch.zeros((1), dtype=dtype, device=device)
        for step in range(num_steps):
            loss_val += loss(mem_rec[step], targets)
        print(loss_val)
        # Gradient calculation + weight update
        loss_val.backward()
        optimizer.step()

        # Store loss history for future plotting
        loss_hist.append(loss_val.item())
        counter += 1
        print_batch_accuracy(net, data, targets, train=True)
# Out:
# Epoch  0  Iteration:  0
# tensor([581.7388], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 33.98%
# Epoch  0  Iteration:  1
# tensor([429.5027], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 55.47%
# Epoch  0  Iteration:  2
# tensor([342.0364], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 65.62%
# Epoch  0  Iteration:  3
# tensor([293.5172], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch:
device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 80.08%
# Epoch  0  Iteration:  99
# tensor([145.7189], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 77.15%
# Epoch  0  Iteration:  100
# tensor([177.4681], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 76.95%
# Epoch  0  Iteration:  101
# tensor([142.3161], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 76.56%
# Epoch  0  Iteration:  102
# tensor([170.4190], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 76.56%
# Epoch  0  Iteration:  103
# tensor([160.7850], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 74.61%
# Epoch  0  Iteration:  104
# tensor([144.6670], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 76.17%
# Epoch  0  Iteration:  105
# tensor([176.4098], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 73.83%
# Epoch  0  Iteration:  106
# tensor([140.9476], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 79.49%
# Epoch  0  Iteration:  107
# tensor([140.9137], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 79.88%
# Epoch  0  Iteration:  108
# tensor([174.5582], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 76.37%
# Epoch  0  Iteration:  109
# tensor([147.0706], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 78.52%
# Epoch  0  Iteration:  110
# tensor([144.1901], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 76.76%
# Epoch  0  Iteration:  111
# tensor([144.3420], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 75.98%
# Epoch  0  Iteration:  112
# tensor([126.8514], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 78.12%
# Epoch  0  Iteration:  113
# tensor([167.5368], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 74.80%
# Epoch  0  Iteration:  114
# tensor([142.4633], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 78.12%
# Epoch  0  Iteration:  115
# tensor([157.2940], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 77.54%
# Epoch  0  Iteration:  116
# tensor([162.7733], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 76.95%
# Epoch  1  Iteration:  117
# tensor([147.8294], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 76.37%
# Epoch  1  Iteration:  118
# tensor([153.1647], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 75.59%
# Epoch  1  Iteration:  119
# tensor([141.3550], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 77.15%
# Epoch  1  Iteration:  120
# tensor([135.8907], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 78.71%
# Epoch  1  Iteration:  121
# tensor([142.2804], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 74.80%
# Epoch  1  Iteration:  122
# tensor([159.8362], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 77.93%
# Epoch  1  Iteration:  123
# tensor([178.7854], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 69.92%
# Epoch  1  Iteration:  124
# tensor([178.3577], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 74.02%
# Epoch  1  Iteration:  125
# tensor([132.4190], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 75.98%
# Epoch  1  Iteration:  126
# tensor([148.8034], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 74.41%
# Epoch  1  Iteration:  127
# tensor([132.6965], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 81.05%
# Epoch  1  Iteration:  128
# tensor([136.5088], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 78.91%
# Epoch  1  Iteration:  129
# tensor([134.1558], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 75.98%
# Epoch  1  Iteration:  130
# tensor([146.2428], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 75.20%
# Epoch  1  Iteration:  131
# tensor([143.5235], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 77.34%
# Epoch  1  Iteration:  132
# tensor([139.2853], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 75.00%
# Epoch  1  Iteration:  133
# tensor([139.0717], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 76.95%
# Epoch  1  Iteration:  134
# tensor([121.6983], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 74.41%
# Epoch  1  Iteration:  135
# tensor([123.0828], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 77.93%
# Epoch  1  Iteration:  136
# tensor([154.6119], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 78.32%
# Epoch  1  Iteration:  137
# tensor([134.1683], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 79.69%
# Epoch  1  Iteration:  138
# tensor([129.2781], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 77.34%
# Epoch  1  Iteration:  139
# tensor([104.9782], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 79.69%
# Epoch  1  Iteration:  140
# tensor([156.6963], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 71.68%
# Epoch  1  Iteration:  141
# tensor([146.6664], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 79.30%
# Epoch  1  Iteration:  142
# tensor([119.5210], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 77.15%
# Epoch  1  Iteration:  143
# tensor([121.2046], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 77.34%
# Epoch  1  Iteration:  144
# tensor([166.7594], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 75.78%
# Epoch  1  Iteration:  145
# tensor([130.5619], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 72.66%
# Epoch  1  Iteration:  146
# tensor([144.0048], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 75.00%
# Epoch  1  Iteration:  147
# tensor([152.2300], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 75.59%
# Epoch  1  Iteration:  148
# tensor([104.4616], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 74.02%
# Epoch  1  Iteration:  149
# tensor([124.0188], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 73.83%
# Epoch  1  Iteration:  150
# tensor([145.7302], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 73.24%
# Epoch  1  Iteration:  151
# tensor([126.9925], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 77.34%
# Epoch  1  Iteration:  152
# tensor([134.5672], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 75.98%
# Epoch  1  Iteration:  153
# tensor([127.8828], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 75.39%
# Epoch  1  Iteration:  154
# tensor([111.5822], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 78.52%
# Epoch  1  Iteration:  155
# tensor([135.1165], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 78.32%
# Epoch  1  Iteration:  156
# tensor([155.2600], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 75.98%
# Epoch  1  Iteration:  157
# tensor([129.6246], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 75.00%
# Epoch  1  Iteration:  158
# tensor([123.4288], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 77.93%
# Epoch  1  Iteration:  159
# tensor([127.5764], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 73.63%
# Epoch  1  Iteration:  160
# tensor([139.1915], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 73.63%
# Epoch  1  Iteration:  161
# tensor([142.9563], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 72.85%
# Epoch  1  Iteration:  162
# tensor([144.0870], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 72.66%
# Epoch  1  Iteration:  163
# tensor([134.9128], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 73.63%
# Epoch  1  Iteration:  164
# tensor([130.0639], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 77.15%
# Epoch  1  Iteration:  165
# tensor([124.0923], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 76.37%
# Epoch  1  Iteration:  166
# tensor([170.9322], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 70.12%
# Epoch  1  Iteration:  167
# tensor([151.2587], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 73.63%
# Epoch  1  Iteration:  168
# tensor([138.7997], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 70.90%
# Epoch  1  Iteration:  169
# tensor([120.5589], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 73.44%
# Epoch  1  Iteration:  170
# tensor([133.7155], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 69.34%
# Epoch  1  Iteration:  171
# tensor([118.4528], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 74.80%
# Epoch  1  Iteration:  172
# tensor([146.8988], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 74.02%
# Epoch  1  Iteration:  173
# tensor([142.8464], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 71.29%
# Epoch  1  Iteration:  174
# tensor([161.4263], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 67.38%
# Epoch  1  Iteration:  175
# tensor([135.8475], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 73.05%
# Epoch  1  Iteration:  176
# tensor([127.6302], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 71.88%
# Epoch  1  Iteration:  177
# tensor([143.6984], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 67.77%
# Epoch  1  Iteration:  178
# tensor([118.7533], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 72.46%
# Epoch  1  Iteration:  179
# tensor([116.2116], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 72.66%
# Epoch  1  Iteration:  180
# tensor([122.9776], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 66.21%
# Epoch  1  Iteration:  181
# tensor([115.5855], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 71.88%
# Epoch  1  Iteration:  182
# tensor([148.1163], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 67.77%
# Epoch  1  Iteration:  183
# tensor([129.7768], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 67.19%
# Epoch  1  Iteration:  184
# tensor([122.5874], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 67.38%
# Epoch  1  Iteration:  185
# tensor([129.1528], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 66.99%
# Epoch  1  Iteration:  186
# tensor([136.8891], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 69.53%
# Epoch  1  Iteration:  187
# tensor([129.6592], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 71.09%
# Epoch  1  Iteration:  188
# tensor([120.7687], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 69.92%
# Epoch  1  Iteration:  189
# tensor([126.3206], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 67.19%
# Epoch  1  Iteration:  190
# tensor([114.1687], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 69.14%
# Epoch  1  Iteration:  191
# tensor([127.3568], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 67.19%
# Epoch  1  Iteration:  192
# tensor([115.3651], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 65.23%
# Epoch  1  Iteration:  193
# tensor([136.7358], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch:
device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 73.83%
# Epoch  2  Iteration:  241
# tensor([96.9153], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 75.98%
# Epoch  2  Iteration:  242
# tensor([117.9505], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 75.78%
# Epoch  2  Iteration:  243
# tensor([115.5129], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 78.52%
# Epoch  2  Iteration:  244
# tensor([113.5897], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 79.10%
# Epoch  2  Iteration:  245
# tensor([91.0702], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 80.08%
# Epoch  2  Iteration:  246
# tensor([134.0022], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 76.37%
# Epoch  2  Iteration:  247
# tensor([129.1035], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 75.20%
# Epoch  2  Iteration:  248
# tensor([118.8055], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 74.61%
# Epoch  2  Iteration:  249
# tensor([124.7723], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 76.76%
# Epoch  2  Iteration:  250
# tensor([112.5420], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 77.34%
# Epoch  2  Iteration:  251
# tensor([99.2913], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 78.12%
# Epoch  2  Iteration:  252
# tensor([121.1589], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 75.20%
# Epoch  2  Iteration:  253
# tensor([134.4411], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 75.78%
# Epoch  2  Iteration:  254
# tensor([118.1853], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 74.02%
# Epoch  2  Iteration:  255
# tensor([132.6723], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 74.80%
# Epoch  2  Iteration:  256
# tensor([136.7624], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 73.44%
# Epoch  2  Iteration:  257
# tensor([136.7772], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 75.98%
# Epoch  2  Iteration:  258
# tensor([136.0605], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 77.34%
# Epoch  2  Iteration:  259
# tensor([122.0516], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 76.76%
# Epoch  2  Iteration:  260
# tensor([100.2047], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 78.71%
# Epoch  2  Iteration:  261
# tensor([100.3920], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 76.37%
# Epoch  2  Iteration:  262
# tensor([106.9616], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 73.44%
# Epoch  2  Iteration:  263
# tensor([123.7407], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 72.46%
# Epoch  2  Iteration:  264
# tensor([114.1294], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 76.56%
# Epoch  2  Iteration:  265
# tensor([121.8783], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 73.83%
# Epoch  2  Iteration:  266
# tensor([117.7459], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 75.20%
# Epoch  2  Iteration:  267
# tensor([107.5965], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 76.95%
# Epoch  2  Iteration:  268
# tensor([113.5096], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 78.52%
# Epoch  2  Iteration:  269
# tensor([114.5474], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 76.95%
# Epoch  2  Iteration:  270
# tensor([110.9066], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 78.71%
# Epoch  2  Iteration:  271
# tensor([141.0876], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 75.20%
# Epoch  2  Iteration:  272
# tensor([106.7754], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 78.91%
# Epoch  2  Iteration:  273
# tensor([113.2147], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 75.98%
# Epoch  2  Iteration:  274
# tensor([118.2838], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 75.39%
# Epoch  2  Iteration:  275
# tensor([109.5722], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 76.37%
# Epoch  2  Iteration:  276
# tensor([143.3660], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 73.24%
# Epoch  2  Iteration:  277
# tensor([146.3575], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 70.90%
# Epoch  2  Iteration:  278
# tensor([130.7103], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 75.20%
# Epoch  2  Iteration:  279
# tensor([130.6272], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 75.20%
# Epoch  2  Iteration:  280
# tensor([121.6053], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 75.39%
# Epoch  2  Iteration:  281
# tensor([108.3295], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 75.78%
# Epoch  2  Iteration:  282
# tensor([126.2197], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 74.61%
# Epoch  2  Iteration:  283
# tensor([110.6164], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 78.52%
# Epoch  2  Iteration:  284
# tensor([139.1444], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 75.78%
# Epoch  2  Iteration:  285
# tensor([109.2815], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 75.59%
# Epoch  2  Iteration:  286
# tensor([118.8720], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 77.73%
# Epoch  2  Iteration:  287
# tensor([91.1286], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 79.88%
# Epoch  2  Iteration:  288
# tensor([110.7292], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 76
device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 81.25%
# Epoch  2  Iteration:  335
# tensor([121.5906], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 81.45%
# Epoch  2  Iteration:  336
# tensor([102.6650], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 82.81%
# Epoch  2  Iteration:  337
# tensor([122.9394], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 83.59%
# Epoch  2  Iteration:  338
# tensor([114.7155], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 82.81%
# Epoch  2  Iteration:  339
# tensor([128.4350], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 83.20%
# Epoch  2  Iteration:  340
# tensor([109.6256], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 86.52%
# Epoch  2  Iteration:  341
# tensor([133.3356], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 84.38%
# Epoch  2  Iteration:  342
# tensor([146.5923], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 77.54%
# Epoch  2  Iteration:  343
# tensor([129.2363], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 82.23%
# Epoch  2  Iteration:  344
# tensor([123.1048], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 84.18%
# Epoch  2  Iteration:  345
# tensor([117.4627], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 87.11%
# Epoch  2  Iteration:  346
# tensor([137.3627], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 80.86%
# Epoch  2  Iteration:  347
# tensor([109.7247], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 83.01%
# Epoch  2  Iteration:  348
# tensor([112.4443], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 81.64%
# Epoch  2  Iteration:  349
# tensor([107.3689], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 83.20%
# Epoch  2  Iteration:  350
# tensor([116.0532], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 84.18%

# %%
# Test set
with torch.no_grad():
    net.eval()
    for test_data, test_targets in test_loader:
        test_data = test_data.to(device)
        test_targets = test_targets.to(device)

        # Test set forward pass
        test_spk, test_mem = net(test_data.view(batch_size, -1))

        # Test set loss
        test_loss = torch.zeros((1), dtype=dtype, device=device)
        for step in range(num_steps):
            test_loss += loss(test_mem[step], test_targets)
        test_loss_hist.append(test_loss.item())

        # Print train/test loss/accuracy
        print_batch_accuracy(net, test_data, test_targets)
# Out:
# Test set accuracy for a single minibatch: 80.08%
# Test set accuracy for a single minibatch: 80.47%
# Test set accuracy for a single minibatch: 80.47%
# Test set accuracy for a single minibatch: 81.25%
# Test set accuracy for a single minibatch: 79.10%
# Test set accuracy for a single minibatch: 81.84%
# Test set accuracy for a single minibatch: 79.69%
# Test set accuracy for a single minibatch: 82.03%
# Test set accuracy for a single minibatch: 80.08%
# Test set accuracy for a single minibatch: 80.86%
# Test set accuracy for a single minibatch: 80.86%
# Test set accuracy for a single minibatch: 81.05%
# Test set accuracy for a single minibatch: 79.30%
# Test set accuracy for a single minibatch: 81.64%
# Test set accuracy for a single minibatch: 80.27%
# Test set accuracy for a single minibatch: 81.84%
# Test set accuracy for a single minibatch: 80.47%
# Test set accuracy for a single minibatch: 78.32%
# Test set accuracy for a single minibatch: 79.88%

# %%
total = 0
correct = 0

# drop_last switched to False to keep all samples
test_loader = DataLoader(fmnist_test, batch_size=batch_size, shuffle=True, drop_last=False)

with torch.no_grad():
  net.eval()
  for data, targets in test_loader:
    data = data.to(device)
    targets = targets.to(device)

    # forward pass
    test_spk, _ = net(data.view(data.size(0), -1))

    # calculate total accuracy
    _, predicted = test_spk.sum(dim=0).max(1)
    total += targets.size(0)
    correct += (predicted == targets).sum().item()

# %%
print(total)
print(correct)
print("{:.2f}".format(100*(correct/total)))
# Out:
# 10000
# 8038
# 80.38
