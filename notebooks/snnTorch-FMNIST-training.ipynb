# %%
# %pip install snntorch
# Out:
# Requirement already satisfied: snntorch in /home/alessandro/tesi/tesi-python/lib/python3.10/site-packages (0.5.3)
# Requirement already satisfied: numpy>=1.17 in /home/alessandro/tesi/tesi-python/lib/python3.10/site-packages (from snntorch) (1.23.5)
# Requirement already satisfied: pandas in /home/alessandro/tesi/tesi-python/lib/python3.10/site-packages (from snntorch) (1.5.2)
# Requirement already satisfied: torch>=1.1.0 in /home/alessandro/tesi/tesi-python/lib/python3.10/site-packages (from snntorch) (1.13.0)
# Requirement already satisfied: matplotlib in /home/alessandro/tesi/tesi-python/lib/python3.10/site-packages (from snntorch) (3.6.2)
# Requirement already satisfied: nvidia-cublas-cu11==11.10.3.66 in /home/alessandro/tesi/tesi-python/lib/python3.10/site-packages (from torch>=1.1.0->snntorch) (11.10.3.66)
# Requirement already satisfied: typing-extensions in /home/alessandro/tesi/tesi-python/lib/python3.10/site-packages (from torch>=1.1.0->snntorch) (4.4.0)
# Requirement already satisfied: nvidia-cudnn-cu11==8.5.0.96 in /home/alessandro/tesi/tesi-python/lib/python3.10/site-packages (from torch>=1.1.0->snntorch) (8.5.0.96)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu11==11.7.99 in /home/alessandro/tesi/tesi-python/lib/python3.10/site-packages (from torch>=1.1.0->snntorch) (11.7.99)
# Requirement already satisfied: nvidia-cuda-runtime-cu11==11.7.99 in /home/alessandro/tesi/tesi-python/lib/python3.10/site-packages (from torch>=1.1.0->snntorch) (11.7.99)
# Requirement already satisfied: setuptools in /home/alessandro/tesi/tesi-python/lib/python3.10/site-packages (from nvidia-cublas-cu11==11.10.3.66->torch>=1.1.0->snntorch) (59.6.0)
# Requirement already satisfied: wheel in /home/alessandro/tesi/tesi-python/lib/python3.10/site-packages (from nvidia-cublas-cu11==11.10.3.66->torch>=1.1.0->snntorch) (0.38.4)
# Requirement already satisfied: packaging>=20.0 in /home/alessandro/tesi/tesi-python/lib/python3.10/site-packages (from matplotlib->snntorch) (22.0)
# Requirement already satisfied: pillow>=6.2.0 in /home/alessandro/tesi/tesi-python/lib/python3.10/site-packages (from matplotlib->snntorch) (9.3.0)
# Requirement already satisfied: pyparsing>=2.2.1 in /home/alessandro/tesi/tesi-python/lib/python3.10/site-packages (from matplotlib->snntorch) (3.0.9)
# Requirement already satisfied: cycler>=0.10 in /home/alessandro/tesi/tesi-python/lib/python3.10/site-packages (from matplotlib->snntorch) (0.11.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /home/alessandro/tesi/tesi-python/lib/python3.10/site-packages (from matplotlib->snntorch) (1.4.4)
# Requirement already satisfied: python-dateutil>=2.7 in /home/alessandro/tesi/tesi-python/lib/python3.10/site-packages (from matplotlib->snntorch) (2.8.2)
# Requirement already satisfied: fonttools>=4.22.0 in /home/alessandro/tesi/tesi-python/lib/python3.10/site-packages (from matplotlib->snntorch) (4.38.0)
# Requirement already satisfied: contourpy>=1.0.1 in /home/alessandro/tesi/tesi-python/lib/python3.10/site-packages (from matplotlib->snntorch) (1.0.6)
# Requirement already satisfied: pytz>=2020.1 in /home/alessandro/tesi/tesi-python/lib/python3.10/site-packages (from pandas->snntorch) (2022.6)
# Requirement already satisfied: six>=1.5 in /home/alessandro/tesi/tesi-python/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib->snntorch) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# # Import librerie

# %%
import numpy as np
import torch
import torch.nn as nn
import snntorch as snn
from snntorch import spikeplot as splt
from torch.utils.data import DataLoader
from torchvision import transforms
from torchvision import datasets
import matplotlib.pyplot as plt

# %% [markdown]
# # Batch size

# %%
batch_size = 512

# %% [markdown]
# # Dataset transformation

# %%
# Define a transform
transform = transforms.Compose([
    transforms.Resize((28, 28)),
    transforms.Grayscale(),
    transforms.ToTensor(),
    transforms.Normalize((0,), (1,))
])

# %%
# dataloader arguments
data_root='../data'

dtype = torch.float
device = torch.device("cuda") if torch.cuda.is_available() else torch.device("cpu")

# %% [markdown]
# # Datasets

# %%
fmnist_train = datasets.FashionMNIST(data_root, train=True, download=True, transform=transform)
fmnist_test = datasets.FashionMNIST(data_root, train=False, download=True, transform=transform)

# %% [markdown]
# # Dataloaders

# %%
# Create DataLoaders
train_loader = DataLoader(fmnist_train, batch_size=batch_size, shuffle=True, drop_last=True)
test_loader = DataLoader(fmnist_test, batch_size=batch_size, shuffle=True, drop_last=True)

# %%
"""
Utilities
"""
def plot_mem_rec(mem_rec, batch_size, targets):
    num_steps = len(mem_rec)
    for i in range(0,batch_size):
        fig = plt.figure()
        ax = fig.subplots()
        ax.set_xlim((-10,210))
        ax.set_ylim((-2,2))
        ss = mem_rec[:,i,:]
        plt.plot(range(0,num_steps), ss.cpu().detach())

        plt.title("Output Layer Membrane Output - {}".format(targets[i]))
        plt.xlabel("Time step")
        plt.ylabel("Neuron Number")
        fig.tight_layout()
    plt.show()


def plot_spk_rec(spk_rec, batch_size, targets):
    for i in range(0,batch_size):
        fig = plt.figure()
        ax = fig.subplots()
        ax.set_xlim((-10,210))
        ax.set_ylim((-1,11))
        ax.set_yticks(range(0,11))
        ss = spk_rec[:,i,:]
        splt.raster(ss, ax, s=1, c="black")

        plt.title("Output Layer - {}".format(targets[i]))
        plt.xlabel("Time step")
        plt.ylabel("Neuron Number")
        fig.tight_layout()
    plt.show()


def print_batch_accuracy(net, data, targets, train=False):
    output, _ = net(data.view(batch_size, -1))
    _, idx = output.sum(dim=0).max(1)
    acc = np.mean((targets == idx).detach().cpu().numpy())

    if train:
        print(f"Train set accuracy for a single minibatch: {acc*100:.2f}%")
    else:
        print(f"Test set accuracy for a single minibatch: {acc*100:.2f}%")

def train_printer():
    print(f"Epoch {epoch}, Iteration {iter_counter}")
    print(f"Train Set Loss: {loss_hist[counter]:.2f}")
    print(f"Test Set Loss: {test_loss_hist[counter]:.2f}")
    print_batch_accuracy(data, targets, train=True)
    print_batch_accuracy(test_data, test_targets, train=False)
    print("\n")

# %% [markdown]
# # Architettura e dinamica temporale

# %%
# Network Architecture
num_inputs = 28*28
num_hidden = 512
num_outputs = 10

# Temporal Dynamics
num_steps = 200
beta = 0.95

# %% [markdown]
# # Definizione della rete

# %%
# Define Network
class Net(nn.Module):
    def __init__(self):
        super().__init__()

        # Initialize layers
        self.fc1 = nn.Linear(num_inputs, num_hidden)
        self.lif1 = snn.Leaky(beta=beta)
        self.fc2 = nn.Linear(num_hidden, num_outputs)
        self.lif2 = snn.Leaky(beta=beta)

    def forward(self, x):

        # Initialize hidden states at t=0
        mem1 = self.lif1.init_leaky()
        mem2 = self.lif2.init_leaky()

        # Record the final layer
        spk2_rec = []
        mem2_rec = []

        for step in range(num_steps):
            cur1 = self.fc1(x)
            spk1, mem1 = self.lif1(cur1, mem1)
            cur2 = self.fc2(spk1)
            spk2, mem2 = self.lif2(cur2, mem2)
            spk2_rec.append(spk2)
            mem2_rec.append(mem2)

        return torch.stack(spk2_rec, dim=0), torch.stack(mem2_rec, dim=0)

# %% [markdown]
# # Creazione della rete

# %%
"""
Network instantiation
"""
net = Net().to(device=device)

# %%
# data, targets = next(iter(train_loader))
# print(data.size())
# print(targets.size())

# %%
# print(data.view(batch_size, -1).size())
# spk_rec, mem_rec = net(data.to(device).view(batch_size,-1))
# print(spk_rec.size())
# print(mem_rec.size())

# %%
# plot_spk_rec(spk_rec=spk_rec, batch_size=batch_size, targets=targets)

# %%
# plot_mem_rec(mem_rec=mem_rec, batch_size=batch_size, targets=targets)

# %%
# loss = nn.CrossEntropyLoss()
# optimizer = torch.optim.Adam(net.parameters(), lr=5e-4, betas=(0.9, 0.999))

# initialize the total loss value
# loss_val = torch.zeros((1), dtype=dtype, device=device)

# sum loss at every step
# for step in range(num_steps):
#   loss_val += loss(mem_rec[step], targets.to(device))

# print(loss_val)

# %%
# clear previously stored gradients
# optimizer.zero_grad()

# calculate the gradients
# loss_val.backward()

# weight update
# optimizer.step()

# %%
# data, targets = next(iter(train_loader))

# %%
# calculate new network outputs using the same data
# spk_rec, mem_rec = net(data.to(device).view(batch_size, -1))

# %%
# initialize the total loss value
# loss_val = torch.zeros((1), dtype=dtype, device=device)

# sum loss at every step
# for step in range(num_steps):
#   loss_val += loss(mem_rec[step], targets.to(device))

# %%
# plot_spk_rec(spk_rec=spk_rec,batch_size=batch_size,targets=targets)

# %%
# plot_mem_rec(mem_rec=mem_rec,batch_size=batch_size,targets=targets)

# %%
run_train = False
state_dict_file_path = "../models/snnTorch-FMNIST-training.pt"

try:
    load_state_dict = torch.load( state_dict_file_path, map_location=device, )
    net.load_state_dict(load_state_dict)
except FileNotFoundError:
    print( "File not found running training" )
    run_train = True

if ( run_train == True ):
    num_epochs = 3
    loss_hist = []
    test_loss_hist = []
    counter = 0
    loss = nn.CrossEntropyLoss()
    optimizer = torch.optim.Adam(net.parameters(), lr=5e-4, betas=(0.9, 0.999))
    net.train()


    # Outer training loop
    for epoch in range(num_epochs):
        # Minibatch training loop
        for data, targets in train_loader:
            print( "Epoch ", epoch, " Iteration: ", counter)
            data = data.to(device)
            targets = targets.to(device)

            # forward pass
            optimizer.zero_grad()
            spk_rec, mem_rec = net(data.view(batch_size, -1))

            # initialize the loss & sum over time
            loss_val = torch.zeros((1), dtype=dtype, device=device)
            for step in range(num_steps):
                loss_val += loss(mem_rec[step], targets)
            print(loss_val)
            # Gradient calculation + weight update
            loss_val.backward()
            optimizer.step()

            # Store loss history for future plotting
            loss_hist.append(loss_val.item())
            counter += 1
            print_batch_accuracy(net, data, targets, train=True)

    torch.save( net.state_dict(), state_dict_file_path )
# Out:
# File not found running training
# Epoch  0  Iteration:  0
# tensor([645.7095], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 29.88%
# Epoch  0  Iteration:  1
# tensor([444.5945], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 48.24%
# Epoch  0  Iteration:  2
# tensor([394.8665], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 50.78%
# Epoch  0  Iteration:  3
# tensor([350.8332], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 54.69%
# Epoch  0  Iteration:  4
# tensor([339.0765], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 56.84%
# Epoch  0  Iteration:  5
# tensor([296.2602], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 64.45%
# Epoch  0  Iteration:  6
# tensor([288.5741], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 59.38%
# Epoch  0  Iteration:  7
# tensor([266.4301], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 63.28%
# Epoch  0  Iteration:  8
# tensor([250.2741], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 65.23%
# Epoch  0  Iteration:  9
# tensor([266.6797], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 61.91%
# Epoch  0  Iteration:  10
# tensor([242.7476], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 58.79%
# Epoch  0  Iteration:  11
# tensor([229.7348], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 67.58%
# Epoch  0  Iteration:  12
# tensor([232.6132], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 63.48%
# Epoch  0  Iteration:  13
# tensor([231.7382], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 63.48%
# Epoch  0  Iteration:  14
# tensor([222.2428], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 63.87%
# Epoch  0  Iteration:  15
# tensor([215.4868], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 65.04%
# Epoch  0  Iteration:  16
# tensor([242.5340], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 64.84%
# Epoch  0  Iteration:  17
# tensor([226.7511], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 66.41%
# Epoch  0  Iteration:  18
# tensor([217.9617], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 69.73%
# Epoch  0  Iteration:  19
# tensor([222.0946], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 64.45%
# Epoch  0  Iteration:  20
# tensor([240.5396], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 65.62%
# Epoch  0  Iteration:  21
# tensor([217.7774], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 65.04%
# Epoch  0  Iteration:  22
# tensor([212.1448], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 65.04%
# Epoch  0  Iteration:  23
# tensor([232.6416], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 65.23%
# Epoch  0  Iteration:  24
# tensor([213.2708], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 65.82%
# Epoch  0  Iteration:  25
# tensor([222.1300], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 66.99%
# Epoch  0  Iteration:  26
# tensor([232.7382], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 62.70%
# Epoch  0  Iteration:  27
# tensor([227.3302], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 67.58%
# Epoch  0  Iteration:  28
# tensor([204.5492], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 65.82%
# Epoch  0  Iteration:  29
# tensor([244.0181], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 61.72%
# Epoch  0  Iteration:  30
# tensor([225.8894], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 63.87%
# Epoch  0  Iteration:  31
# tensor([229.3220], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 67.77%
# Epoch  0  Iteration:  32
# tensor([249.3078], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch:
device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 76.56%
# Epoch  1  Iteration:  132
# tensor([157.8380], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 78.12%
# Epoch  1  Iteration:  133
# tensor([165.8143], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 75.39%
# Epoch  1  Iteration:  134
# tensor([148.0074], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 78.71%
# Epoch  1  Iteration:  135
# tensor([151.0072], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 77.34%
# Epoch  1  Iteration:  136
# tensor([158.4397], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 79.49%
# Epoch  1  Iteration:  137
# tensor([141.8173], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 76.37%
# Epoch  1  Iteration:  138
# tensor([143.2372], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 77.34%
# Epoch  1  Iteration:  139
# tensor([149.6362], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 77.15%
# Epoch  1  Iteration:  140
# tensor([139.7129], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 77.15%
# Epoch  1  Iteration:  141
# tensor([155.3240], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 72.27%
# Epoch  1  Iteration:  142
# tensor([160.4523], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 77.15%
# Epoch  1  Iteration:  143
# tensor([136.8643], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 75.39%
# Epoch  1  Iteration:  144
# tensor([126.9887], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 79.69%
# Epoch  1  Iteration:  145
# tensor([188.9895], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 75.39%
# Epoch  1  Iteration:  146
# tensor([143.7836], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 74.02%
# Epoch  1  Iteration:  147
# tensor([137.6972], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 76.37%
# Epoch  1  Iteration:  148
# tensor([153.0208], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 75.78%
# Epoch  1  Iteration:  149
# tensor([153.3511], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 75.98%
# Epoch  1  Iteration:  150
# tensor([151.0202], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 75.98%
# Epoch  1  Iteration:  151
# tensor([146.5370], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 75.59%
# Epoch  1  Iteration:  152
# tensor([122.7181], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 78.91%
# Epoch  1  Iteration:  153
# tensor([144.4192], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 76.17%
# Epoch  1  Iteration:  154
# tensor([143.8517], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 75.59%
# Epoch  1  Iteration:  155
# tensor([147.4905], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 76.37%
# Epoch  1  Iteration:  156
# tensor([130.9807], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 77.73%
# Epoch  1  Iteration:  157
# tensor([144.8741], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 76.37%
# Epoch  1  Iteration:  158
# tensor([150.7874], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 75.00%
# Epoch  1  Iteration:  159
# tensor([142.9837], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 78.32%
# Epoch  1  Iteration:  160
# tensor([154.8040], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 77.34%
# Epoch  1  Iteration:  161
# tensor([147.5185], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 76.37%
# Epoch  1  Iteration:  162
# tensor([128.2725], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 78.32%
# Epoch  1  Iteration:  163
# tensor([176.7305], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 74.80%
# Epoch  1  Iteration:  164
# tensor([144.3021], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 74.22%
# Epoch  1  Iteration:  165
# tensor([158.8195], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 77.54%
# Epoch  1  Iteration:  166
# tensor([146.4029], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 74.80%
# Epoch  1  Iteration:  167
# tensor([153.7957], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 77.93%
# Epoch  1  Iteration:  168
# tensor([148.0905], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 74.02%
# Epoch  1  Iteration:  169
# tensor([164.6042], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 74.41%
# Epoch  1  Iteration:  170
# tensor([154.1432], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 75.39%
# Epoch  1  Iteration:  171
# tensor([132.5047], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 75.00%
# Epoch  1  Iteration:  172
# tensor([143.9225], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 80.47%
# Epoch  1  Iteration:  173
# tensor([178.2320], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 75.00%
# Epoch  1  Iteration:  174
# tensor([137.6916], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 79.88%
# Epoch  1  Iteration:  175
# tensor([152.7141], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 75.39%
# Epoch  1  Iteration:  176
# tensor([139.2815], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 78.12%
# Epoch  1  Iteration:  177
# tensor([132.0635], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 74.80%
# Epoch  1  Iteration:  178
# tensor([112.9744], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 75.59%
# Epoch  1  Iteration:  179
# tensor([171.0471], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 75.00%
# Epoch  1  Iteration:  180
# tensor([122.5402], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 74.41%
# Epoch  1  Iteration:  181
# tensor([122.0950], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 74.22%
# Epoch  1  Iteration:  182
# tensor([152.4144], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 71.68%
# Epoch  1  Iteration:  183
# tensor([120.4985], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 76.76%
# Epoch  1  Iteration:  184
# tensor([133.8826], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 76.95%
# Epoch  1  Iteration:  185
# tensor([146.2374], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 75.00%
# Epoch  1  Iteration:  186
# tensor([144.3859], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 79.30%
# Epoch  1  Iteration:  187
# tensor([140.6671], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 69.53%
# Epoch  1  Iteration:  188
# tensor([133.9302], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 75.59%
# Epoch  1  Iteration:  189
# tensor([184.8285], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 73.24%
# Epoch  1  Iteration:  190
# tensor([137.2102], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 72.85%
# Epoch  1  Iteration:  191
# tensor([129.7488], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 77.93%
# Epoch  1  Iteration:  192
# tensor([149.1570], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 76.95%
# Epoch  1  Iteration:  193
# tensor([144.2144], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 74.61%
# Epoch  1  Iteration:  194
# tensor([190.1567], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 70.31%
# Epoch  1  Iteration:  195
# tensor([139.6242], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 74.02%
# Epoch  1  Iteration:  196
# tensor([130.5786], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 74.80%
# Epoch  1  Iteration:  197
# tensor([131.3450], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 73.83%
# Epoch  1  Iteration:  198
# tensor([129.5425], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 78.52%
# Epoch  1  Iteration:  199
# tensor([140.1180], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 74.80%
# Epoch  1  Iteration:  200
# tensor([163.9693], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 75.98%
# Epoch  1  Iteration:  201
# tensor([156.4218], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 72.07%
# Epoch  1  Iteration:  202
# tensor([169.9022], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 74.41%
# Epoch  1  Iteration:  203
# tensor([194.0982], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 71.88%
# Epoch  1  Iteration:  204
# tensor([171.2337], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 72.07%
# Epoch  1  Iteration:  205
# tensor([140.9475], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 67.77%
# Epoch  1  Iteration:  206
# tensor([140.6939], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 71.48%
# Epoch  1  Iteration:  207
# tensor([151.0155], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 69.14%
# Epoch  1  Iteration:  208
# tensor([167.0337], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 68.55%
# Epoch  1  Iteration:  209
# tensor([168.0591], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 67.97%
# Epoch  1  Iteration:  210
# tensor([147.2100], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 71.09%
# Epoch  1  Iteration:  211
# tensor([152.9133], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 71.68%
# Epoch  1  Iteration:  212
# tensor([162.6811], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 66.80%
# Epoch  1  Iteration:  213
# tensor([135.6965], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 70.12%
# Epoch  1  Iteration:  214
# tensor([158.6427], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 71.29%
# Epoch  1  Iteration:  215
# tensor([138.8372], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 67.97%
# Epoch  1  Iteration:  216
# tensor([133.9382], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 64.06%
# Epoch  1  Iteration:  217
# tensor([150.5338], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 68.36%
# Epoch  1  Iteration:  218
# tensor([141.6644], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 67.19%
# Epoch  1  Iteration:  219
# tensor([148.1147], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 68.16%
# Epoch  1  Iteration:  220
# tensor([127.1282], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 64.26%
# Epoch  1  Iteration:  221
# tensor([158.0262], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 65.23%
# Epoch  1  Iteration:  222
# tensor([151.4586], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 69.92%
# Epoch  1  Iteration:  223
# tensor([142.7025], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 69.34%
# Epoch  1  Iteration:  224
# tensor([133.8154], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 69.34%
# Epoch  1  Iteration:  225
# tensor([169.9510], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 69.73%
# Epoch  1  Iteration:  226
# tensor([116.4318], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 73.63%
# Epoch  1  Iteration:  227
# tensor([131.0118], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 71.68%
# Epoch  1  Iteration:  228
# tensor([122.0488], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 69.73%
# Epoch  1  Iteration:  229
# tensor([107.6031], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 75.39%
# Epoch  1  Iteration:  230
# tensor([143.0814], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 70.12%
# Epoch  1  Iteration:  231
# tensor([126.4821], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch:
device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 71.68%
# Epoch  2  Iteration:  331
# tensor([113.4451], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 68.55%
# Epoch  2  Iteration:  332
# tensor([108.6419], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 73.83%
# Epoch  2  Iteration:  333
# tensor([126.8126], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 71.68%
# Epoch  2  Iteration:  334
# tensor([122.9565], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 67.58%
# Epoch  2  Iteration:  335
# tensor([130.6515], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 67.38%
# Epoch  2  Iteration:  336
# tensor([133.6343], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 69.34%
# Epoch  2  Iteration:  337
# tensor([141.0610], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 68.36%
# Epoch  2  Iteration:  338
# tensor([103.5820], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 68.55%
# Epoch  2  Iteration:  339
# tensor([139.1845], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 68.36%
# Epoch  2  Iteration:  340
# tensor([127.5754], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 67.19%
# Epoch  2  Iteration:  341
# tensor([99.0535], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 68.95%
# Epoch  2  Iteration:  342
# tensor([117.6012], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 69.73%
# Epoch  2  Iteration:  343
# tensor([142.8791], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 72.85%
# Epoch  2  Iteration:  344
# tensor([103.2744], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 69.14%
# Epoch  2  Iteration:  345
# tensor([122.6644], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 68.36%
# Epoch  2  Iteration:  346
# tensor([113.6809], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 70.90%
# Epoch  2  Iteration:  347
# tensor([117.9907], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 69.34%
# Epoch  2  Iteration:  348
# tensor([113.6122], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 67.38%
# Epoch  2  Iteration:  349
# tensor([118.6334], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 67.97%
# Epoch  2  Iteration:  350
# tensor([131.8143], device='cuda:0', grad_fn=<AddBackward0>)
# Train set accuracy for a single minibatch: 62.11%

# %%
# Test set
with torch.no_grad():
    net.eval()
    for test_data, test_targets in test_loader:
        test_data = test_data.to(device)
        test_targets = test_targets.to(device)

        # Test set forward pass
        test_spk, test_mem = net(test_data.view(batch_size, -1))

        # Test set loss
        test_loss = torch.zeros((1), dtype=dtype, device=device)
        for step in range(num_steps):
            test_loss += loss(test_mem[step], test_targets)
        test_loss_hist.append(test_loss.item())

        # Print train/test loss/accuracy
        print_batch_accuracy(net, test_data, test_targets)
# Out:
# Test set accuracy for a single minibatch: 70.90%
# Test set accuracy for a single minibatch: 62.89%
# Test set accuracy for a single minibatch: 69.34%
# Test set accuracy for a single minibatch: 69.14%
# Test set accuracy for a single minibatch: 64.45%
# Test set accuracy for a single minibatch: 65.23%
# Test set accuracy for a single minibatch: 68.75%
# Test set accuracy for a single minibatch: 62.70%
# Test set accuracy for a single minibatch: 66.60%
# Test set accuracy for a single minibatch: 67.38%
# Test set accuracy for a single minibatch: 66.21%
# Test set accuracy for a single minibatch: 66.99%
# Test set accuracy for a single minibatch: 67.58%
# Test set accuracy for a single minibatch: 66.80%
# Test set accuracy for a single minibatch: 70.51%
# Test set accuracy for a single minibatch: 64.84%
# Test set accuracy for a single minibatch: 60.94%
# Test set accuracy for a single minibatch: 68.95%
# Test set accuracy for a single minibatch: 66.02%

# %%
total = 0
correct = 0

# drop_last switched to False to keep all samples
test_loader = DataLoader(fmnist_test, batch_size=batch_size, shuffle=True, drop_last=False)

with torch.no_grad():
  net.eval()
  for data, targets in test_loader:
    data = data.to(device)
    targets = targets.to(device)

    # forward pass
    test_spk, _ = net(data.view(data.size(0), -1))

    # calculate total accuracy
    _, predicted = test_spk.sum(dim=0).max(1)
    total += targets.size(0)
    correct += (predicted == targets).sum().item()

# %%
print(total)
print(correct)
print("{:.2f}".format(100*(correct/total)))
# Out:
# 10000
# 6680
# 66.80
